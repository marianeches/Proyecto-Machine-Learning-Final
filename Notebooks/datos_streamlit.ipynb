# %%
import pandas as pd
import numpy as np

# %%
hotel = pd.read_csv('../data/train.csv')
hotel
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     2                  3
# 1                 2               0                     0                  3
# 2                 2               0                     1                  2
# 3                 2               0                     2                  2
# 4                 2               0                     0                  3
# ...             ...             ...                   ...                ...
# 29015             1               0                     2                  5
# 29016             2               0                     0                  2
# 29017             3               0                     0                  4
# 29018             1               0                     0                  3
# 29019             2               0                     0                  1
#
# ...
