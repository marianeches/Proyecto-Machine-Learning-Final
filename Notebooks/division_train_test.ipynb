# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
hotel = pd.read_csv('../processed/hotel_dataset_modificado.csv')
hotel
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
X = hotel.drop(['booking_status'], axis= 1)
y = hotel['booking_status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (36275, 15)
# (29020, 15)
# (7255, 15)
# (29020,)
# (7255,)

# %%
train = pd.concat([X_train, y_train], axis= 1)

# %%
nombre_archivo = 'train.csv'

# %%
train.to_csv(nombre_archivo, index=False)

# %%
test = pd.concat([X_test, y_test], axis= 1)

# %%
nombre_archivo_test = 'test.csv'

# %%
test.to_csv(nombre_archivo_test, index=False)

# %%
train
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 26817             2               0                     2                  3
# 7537              2               0                     0                  3
# 6217              2               0                     1                  2
# 22883             2               0                     2                  2
# 28669             2               0                     0                  3
# ...             ...             ...                   ...                ...
# 20757             1               0                     2                  5
# 32103             2               0                     0                  2
# 30403             3               0                     0                  4
# 21243             1               0                     0                  3
# 2732              2               0                     0                  1
#
# ...

# %%
test
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 16432             3               0                     2                  3
# 15128             2               0                     0                  3
# 16842             2               0                     0                  2
# 5488              2               0                     2                  4
# 31896             2               0                     0                  2
# ...             ...             ...                   ...                ...
# 10946             2               0                     2                  3
# 15821             2               0                     2                  0
# 29141             2               0                     0                  2
# 8656              1               0                     2                  0
# 26894             2               0                     4                  6
#
# ...
